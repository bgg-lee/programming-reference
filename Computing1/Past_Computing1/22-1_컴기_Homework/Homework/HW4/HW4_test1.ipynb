# %% [markdown]
# # HW4_test

# %% [markdown]
# # P1
# ![image-2.png](attachment:image-2.png)

# %%
P1_input1 = [1, 2, 3, 1]
P1_input2 = [1, 1, 2, 3, 3, 3]
P1_input3 = [1, 2, 3, 4, 5]
P1_input4 = []

# %%
# %run P1.py

# %%
P1(P1_input1)
# Out:
# {1}

# %%
P1(P1_input2)
# Out:
# {1, 3}

# %%
P1(P1_input3)
# Out:
# set()

# %%
P1(P1_input4)
# Out:
# set()

# %% [markdown]
# # P2
#
# ![image-2.png](attachment:image-2.png)

# %%
P2_a1, P2_a2  = ['red', 'yellow', 'purple'], ['apple', 'banana', 'grape']
P2_b1, P2_b2 = [1, 2, 3], ['computer', 'keyboard', 'mouse']
P2_c1, P2_c2 = [], []

# %%
# %run P2.py

# %%
P2(P2_a1, P2_a2)
# Out:
# {('purple', 'grape'), ('red', 'apple'), ('yellow', 'banana')}

# %%
P2(P2_b1, P2_b2)
# Out:
# {(1, 'computer'), (2, 'keyboard'), (3, 'mouse')}

# %%
P2(P2_c1, P2_c2)
# Out:
# set()

# %% [markdown]
# # P3
# ![image-3.png](attachment:image-3.png)

# %%
P3_input1 = {'red': 1, 'green': 1, 'blue': 2}
P3_input2 = {(1,2): 'a', 'g': 3, 1: True}
P3_input3 = {}
P3_input4 = {'a': True, 'b': True, 'c': True}

# %%
# %run P3.py

# %%
P3(P3_input1)
# Out:
# 2

# %%
P3(P3_input2)
# Out:
# 3

# %%
P3(P3_input3)
# Out:
# 0

# %%
P3(P3_input4)
# Out:
# 1

# %% [markdown]
# # P4
# ![image-2.png](attachment:image-2.png)

# %%
P4_input1 = {'neutron': 0.55, 'proton': 0.21, 'meson': 0.03, 'muon': 0.07, 'neutrino': 0.14}
P4_input2 = {'neutron': 0.11, 'proton': 0.21, 'meson': 0.05, 'muon': 0.09, 'neutrino': 0.12}
P4_input3 = {'a': 0.5}
P4_input4 = dict()

# %%
sample_case = [
{'jgoodall' : {'surname' : 'Goodall',
'forename' : 'Jane',
'born' : 1934,
'died' : None,
'notes' : 'primate researcher',
'author' : ['In the Shadow of Man','The Chimpanzees of Gombe']},
'rfranklin' : {'surname' : 'Franklin',
'forename' : 'Rosalind',
'born' : 1920,
'died' : 1957,
'notes' : 'contributed to discovery of DNA'},
'rcarson' : {'surname' : 'Carson',
'forename' : 'Rachel',
'born' : 1907,
'died' : 1964,
'notes' : 'raised awareness of effects of DDT',
'author' : ['Silent Spring']}
},
{'jgoodall' : {'surname' : 'Goodall',
'forename' : 'Jane',
'born' : 1934,
'died' : None},
'rfranklin' : {'surname' : 'Franklin',
'forename' : 'Rosalind',
'born' : 1920,
'died' : 1957,
'notes' : 'contributed to discovery of DNA'},
'rcarson' : {'surname' : 'Carson',
'forename' : 'Rachel',
'born' : 1907,
'died' : 1964,
'notes' : 'raised awareness of effects of DDT',
'author' : ['Silent Spring']}
},
{'jgoodall' : {'surname' : 'Goodall',
'forename' : 'Jane',
'born' : 1934,
'died' : None,
'notes' : 'primate researcher',
'author' : ['In the Shadow of Man','The Chimpanzees of Gombe']},
'rfranklin' : {'surname' : 'Franklin',
'forename' : 'Rosalind',
'born' : 1920,
'died' : 1957,
'notes' : 'contributed to discovery of DNA',
'author' : ['In the Shadow of Man','The Chimpanzees of Gombe']},
'rcarson' : {'surname' : 'Carson',
'forename' : 'Rachel',
'born' : 1907,
'died' : 1964,
'notes' : 'raised awareness of effects of DDT',
'author' : ['Silent Spring']}
},
{'jgoodall' : {'surname' : 'Goodall',
'forename' : 'Jane',
'born' : 1934,
'notes' : 'primate researcher',
'author' : ['In the Shadow of Man','The Chimpanzees of Gombe']},
'rfranklin' : {'surname' : 'Franklin',
'forename' : 'Rosalind',
'born' : 1920,
'died' : 1957,
'notes' : 'contributed to discovery of DNA',
'author' : ['In the Shadow of Man','The Chimpanzees of Gombe']},
'rcarson' : {'surname' : 'Carson',
'forename' : 'Rachel',
'died' : 1964,
'notes' : 'raised awareness of effects of DDT',
'author' : ['Silent Spring']}
},
{'a': {'aa':123, 'ab': [1,2]}, 'b': {'aa': 'bb', 'ab': 'cc'}},
{'a': {'aa':123, 'ab': [1,2]}, 'b': {'aa': 'bb', 'ab': 'cc'}, 'c':
{'aa': 1, 'ab': 2}},
{'A': {1: 'a', 2: 'b'}, 'B': {1: 'a', 2: 'c', 3: 'd'}},
{(1,2): {1: 'a', 2: 'b'}, (2,3): {1: 'c', 2: 'd'}},
{(1,2): {1: 'a', 2: 'b'}, (2,3): {1: 'c', 2: 'd'}, (2,4): {1: 'a', 2:
'd'}, (3,4): {1: 'c', 2: 'd'}},
{'a': {'aa':123, 'ab': [1,2]}, 'b': {}}
]

# %%
# %run P4.py

# %%
P4(P4_input1)
# Out:
# 'neutron'

# %%
P4(P4_input2)
# Out:
# 'proton'

# %%
P4(P4_input3)
# Out:
# 'a'

# %%
P4(P4_input4)
# Out:
# ''

# %%
for i in sample_case:
    P4(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#       1 for i in sample_case:
# ----> 2     P4(i)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/(서울대)/22.03_1학년1학기/데이터사이언스를 위한 컴퓨팅의 기초/Homework/HW4/P4.py:7, in P4(dct)
#       4 ans = ""
#       6 for key, value in dct.items():
# ----> 7     if value == max(dct.values()):
#       8         ans = key
#      10 return ans
#
# TypeError: '>' not supported between instances of 'dict' and 'dict'

# %% [markdown]
# # P5
# ![image-3.png](attachment:image-3.png)

# %%
P5_input1 = {'red': 1, 'green': 1, 'blue': 2}
P5_input2 = {'r': 'a', 'g': 'b', 'b': 'c'}
P5_input3 = {'a': True, 'b': True, 'c': 2, 'd': 2}
P5_input4 = {}
P5_input5 = {'1':False, '2':0, '3': True, '34': 1}

# %%
# %run P5.py

# %%
P5(P5_input1)
# Out:
# [1]

# %%
P5(P5_input2)
# Out:
# []

# %%
P5(P5_input3)
# Out:
# [True, 2]

# %%
P5(P5_input4)
# Out:
# []

# %%
P5(P5_input5)
# Out:
# [False, True]

# %% [markdown]
# # P6
# ![image-3.png](attachment:image-3.png)

# %%
P6_a1, P6_a2 = {'a': 1, 'b': True, 'c': [1,2]}, {'a': 1, 'b': 123, 'c': [1,2]}
P6_b1, P6_b2 = {'a': 1, 'b': True }, {'c': 1, 'd': 123, 'e': [1,2]}
P6_c1, P6_c2 = {}, {'c': 1, 'd': 123, 'e': [1,2]}
P6_d1, P6_d2 = {}, {}

# %%
# %run P6.py

# %%
P6(P6_a1, P6_a2)
# Out:
# {'a': 1, 'c': [1, 2]}

# %%
P6(P6_b1, P6_b2)
# Out:
# {}

# %%
P6(P6_c1, P6_c2)
# Out:
# {}

# %%
P6(P6_d1, P6_d2)
# Out:
# {}

# %% [markdown]
# # P7
# ![image-2.png](attachment:image-2.png)

# %%
P7_input1 = {'a': {'aa':123, 'ab': [1,2]}, 'b': {'aa': 'bb', 'ab': 'cc'}}
P7_input2 = {'A': {1: 'a', 2: 'b'}, 'B': {2: 'c', 3: 'd'}}
P7_input3 = { 'jgoodall' : {'surname' : 'Goodall',
                'forename' : 'Jane',
                'born' : 1934,
                'died' : None,
                'notes' : 'primate researcher',
                'author' : ['In the Shadow of Man','The Chimpanzees of Gombe']},
    'rfranklin' : {'surname' : 'Franklin',
                'forename' : 'Rosalind',
                'born' : 1920,
                'died' : 1957,
                'notes' : 'contributed to discovery of DNA'},
    'rcarson' : {'surname' : 'Carson',
                'forename' : 'Rachel',
                'born' : 1907,
                'died' : 1964,
                'notes' : 'raised awareness of effects of DDT',
                'author' : ['Silent Spring'] }
            }
P7_input4 = {'A': {1: 'a', 2: 'b'}}

# %%
# %run P7.py

# %%
P7(P7_input1)
# Out:
# 1

# %%
P7(P7_input2)
# Out:
# 0

# %%
P7(P7_input3)
# Out:
# 1

# %%
P7(P7_input4)
# Out:
# 1

# %% [markdown]
# # P8
# ![image-2.png](attachment:image-2.png)

# %%
P8_input1 = {'R': 0.2, 'G': 0.3, 'B': 0.5}
P8_input2 = {'R': 0.2, 'G': 0.3, 'B': 0.6}
P8_input3 = {'R': 0.1, 'G': 0.1, 'B': 0.1}

# %%
# %run P8.py

# %%
P8(P8_input1)
# Out:
# True

# %%
P8(P8_input2)
# Out:
# False

# %%
P8(P8_input3)
# Out:
# False

# %% [markdown]
# # P9
# ![image-3.png](attachment:image-3.png)

# %%
P9_a1, P9_a2 = {0:1, 6:3}, {0:2, 5:2, 6:2, 7:1}
P9_b1, P9_b2 = {0:1, 6:3}, {1:-1, 2:2, 3:2, 4:1}
P9_c1, P9_c2 = {0:1, 6:-3}, {0:-1, 6:3}
P9_d1, P9_d2 = {1:-1, 2:2, 3:2, 4:1}, {0:1, 6:3}

# %%
# %run P9.py

# %%
P9(P9_a1, P9_a2)
# Out:
# 8

# %%
P9(P9_b1, P9_b2)
# Out:
# 0

# %%
P9(P9_c1, P9_c2)
# Out:
# -10

# %%
P9(P9_d1, P9_d2)
# Out:
# 0

# %% [markdown]
# # P10
# ![image-2.png](attachment:image-2.png)

# %%
q_1={"data", "science"}
k1 = "data"
q_2= {"data", "science"}
k2 = "daaa"

# %%
q_3= {"data", "science"}
k3 = "scienzz"
q_4= {"data", "science", "scienze"}
k4 = "scienzz"

# %%
q_5= {"", "sc"}
k5 = ""
q_6= {"a", "f", "c", 'd','e'}
k6 = "b"

# %%
# %run P10.py

# %%
P10(q_1, k1)
# Out:
# False

# %%
P10(q_2, k2)
# Out:
# True

# %%
P10(q_3, k3)
# Out:
# False

# %%
P10(q_4, k4)
# Out:
# True

# %%
P10(q_5, k5)
# Out:
# False

# %%
P10(q_6, k6)
# Out:
# True
