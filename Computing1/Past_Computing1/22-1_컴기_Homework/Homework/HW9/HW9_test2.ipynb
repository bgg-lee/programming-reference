# %% [markdown]
# # HW9_test

# %%
from linked_list_helper import *

# %% [markdown]
# # P1
# ![image-6.png](attachment:image-6.png)

# %%
P1_input1 = '()'
P1_input2 = '()[]{}'
P1_input3 = '([)]'

# %%
from P1 import P1

# %%
P1(P1_input1)
# Out:
# True

# %%
P1(P1_input2)
# Out:
# True

# %%
P1(P1_input3)
# Out:
# False

# %%
P1("([{")
# Out:
# False

# %%
P1(")")
# Out:
# False

# %%
P1("{")
# Out:
# False

# %%
P1("({[]})[]{}")
# Out:
# True

# %% [markdown]
# # P2
# ![image-7.png](attachment:image-7.png)

# %%
from P2 import P2

# %%
P2([500,600,700,300,100,400,800,500])
# Out:
# [1, 1, 4, 2, 1, 1, 0, 0]

# %%
P2([100,200,100,500,300,300,50])
# Out:
# [1, 2, 1, 0, 0, 0, 0]

# %%
P2([9,8,7,10,9,8,7])
# Out:
# [3, 2, 1, 0, 0, 0, 0]

# %%
P2([100,200,100,500,300,300,400])
# Out:
# [1, 2, 1, 0, 2, 1, 0]

# %%
P2([100,50,100,200,200,50,50,400])
# Out:
# [3, 1, 1, 4, 3, 2, 1, 0]

# %%
P2([0,200,300])
# Out:
# [1, 1, 0]

# %%
P2([200,0,300])
# Out:
# [2, 1, 0]

# %% [markdown]
# # P3
# ![image-7.png](attachment:image-7.png)

# %%
from P3 import P3

# %%
l1 = create_linked_list([4,2,1,3])
print_linked_list(P3(l1),[])
# Out:
# [3, 1, 2, 4]

# %%
l2 = create_linked_list([-1,5,0,2,3])
print_linked_list(P3(l2),[])
# Out:
# [3, 2, 0, 5, -1]

# %%
l2 = create_linked_list([5])
print_linked_list(P3(l2),[])
# Out:
# [5]

# %%
l2 = create_linked_list([-5,-3,0,1,2,3])
print_linked_list(P3(l2),[])
# Out:
# [3, 2, 1, 0, -3, -5]

# %%
l3 = create_linked_list([])
print_linked_list(P3(l3),[])
# Out:
# []

# %% [markdown]
# # P4
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)

# %%
from P4 import P4

# %%
l1 = create_linked_list([1,1,1]) 
l2 = create_linked_list([1,1,1])
print_linked_list(P4(l1, l2),[])
# Out:
# [2, 2, 2]

# %%
l1 = create_linked_list([0]) 
l2 = create_linked_list([0])
print_linked_list(P4(l1, l2),[])
# Out:
# [0]

# %%
l1 = create_linked_list([0]) 
l2 = create_linked_list([1])
print_linked_list(P4(l1, l2),[])
# Out:
# [1]

# %%
l1 = create_linked_list([5,5,5])
l2 = create_linked_list([5,5,5])
print_linked_list(P4(l1, l2),[])
# Out:
# [1, 1, 1, 0]

# %%
l1 = create_linked_list([5,5,5])
l2 = create_linked_list([5,5])
print_linked_list(P4(l1, l2),[])
# Out:
# [6, 1, 0]

# %%
l1 = create_linked_list([9,9])
l2 = create_linked_list([9])
print_linked_list(P4(l1, l2),[])
print(99 + 9)
# Out:
# [1, 0, 8]
# 108

# %%
l1 = create_linked_list([5,5,8,0])
l2 = create_linked_list([1,2])
print_linked_list(P4(l1, l2),[])
print(5580+12)
# Out:
# [5, 5, 9, 2]
# 5592

# %%
l1 = create_linked_list([])
l2 = create_linked_list([])
print_linked_list(P4(l1, l2),[])
# Out:
# []

# %%
l1 = create_linked_list([9,8,9,8,9])
l2 = create_linked_list([2,3])
print_linked_list(P4(l1, l2),[])
print(98989+23)
# Out:
# [9, 9, 0, 1, 2]
# 99012

# %%
l1 = create_linked_list([9,8])
l2 = create_linked_list([1,2,3])
print_linked_list(P4(l1, l2),[])
print(123+98)
# Out:
# [2, 2, 1]
# 221

# %%
l1 = create_linked_list([9,8])
l2 = create_linked_list([1,2,3])
a = P4(l1, l2)
print(a)
print(a.val)
print(a.next.val)
print(a.next.next.val)
# Out:
# ...
# 2
# 2
# 1

# %%
l1 = create_linked_list([9])
l2 = create_linked_list([8])
print_linked_list(P4(l1, l2),[])
print(9+8)
# Out:
# [1, 7]
# 17

# %% [markdown]
# ## cf

# %%
l1 = create_linked_list([1,2,3])
l2 = create_linked_list([4,5,6])

print(get_fin(l1).val)
print(get_fin(l2).val)
pop_fin(l1)
print_linked_list(l1,[])
pop_fin(l2)
print_linked_list(l2,[])
print(get_fin(l1).val)
print(get_fin(l2).val)
pop_fin(l1)
print_linked_list(l1,[])
pop_fin(l2)
print_linked_list(l2,[])
print(get_fin(l1).val)
print(get_fin(l2).val)
pop_fin(l1)
print_linked_list(l1,[])
pop_fin(l2)
print_linked_list(l2,[])
print(get_fin(l1).val)
print(get_fin(l2).val)
# Out:
# 3
# 6
# [1, 2]
# [4, 5]
# 2
# 5
# [1]
# [4]
# 1
# 4
# [1]
# [4]
# 1
# 4

# %%
from linked_list_helper import ListNode
from linked_list_helper import create_linked_list, print_linked_list

def P4(num1: ListNode, num2: ListNode) -> ListNode: 
    ##### Write your Code Here #####
    def pop_fin(curNode: ListNode) -> ListNode:
        prev = curNode
        if curNode:
            while curNode.next != None:
                prev = curNode
                curNode = curNode.next
            if prev.next != None:
                prev.next = None
            else:
                curNode.val = None
        else:
            return None

    def get_fin(curNode: ListNode) -> ListNode:
        num_fin = curNode
        if curNode:
            while curNode.next != None:
                curNode = curNode.next
                num_fin = curNode
            return num_fin
        else:
            return None

    def get_size(curNode: ListNode) -> ListNode:
        size = 0
        if curNode:
            size = 1
            while curNode.next != None:
                curNode = curNode.next
                size += 1
            return size
        else:
            return None
    
    def sort(curNode: ListNode) -> ListNode: 
        next = None
        curr = curNode
        prev = None
        while (curr != None):
            next = curr.next
            curr.next = prev
            prev = curr
            curr = next
        return prev

    def get_next(curNode: ListNode, x: int) -> ListNode:
        try:
            return curNode.next
        except:
            return None
        
    def get_value(curNode: ListNode) -> int:
        if curNode = None:
            return 0
        else:
            return curNode.val

    
#     def add_fin(num1: ListNode, num2:ListNode) -> None:
#         a = get_size(num1)
#         b = get_size(num2)
#         if a > b:
#             ans = create_linked_list([0 for i in range(a)])
#         else:
#             ans = create_linked_list([0 for i in range(b)])

#         while get_fin(num1).val or get_fin(num2).val:
#             if get_fin(num1).val == None:
#                 ans.val = (0 + get_fin(num2).val)
#                 pop(num2)
#             elif get_fin(num2).val == None:
#                 ans.val =(get_fin(num1).val + 0)
#                 pop(num1)
#             else:
#                 ans.val = (get_fin(num1).val + get_fin(num2).val)
#                 pop(num1)
#                 pop(num2)
                
    print(get_fin(num1))
    def add_fin(num1: ListNode, num2:ListNode) -> ListNode:
        while get_fin(num1).val or get_fin(num2).val:
            if get_fin(num1).val == None:
                return  (0 + get_fin(num2).val)
            elif get_fin(num2).val == None:
                return (get_fin(num1).val + 0)
            else:
                return  (get_fin(num1).val + get_fin(num2).val)   
        
    a = get_size(num1)
    b = get_size(num2)
    
    if a == None or b == None:
        ans = None
    elif a > b:
        ans = create_linked_list([0 for i in range(a)])
    else:
        ans = create_linked_list([0 for i in range(b)])
    
    print_linked_list(ans,[])
    
#     while get_fin(num1).val or get_fin(num2).val:
    ans.val = add_fin(num1, num2)
    pop_fin(num1)
    pop_fin(num2)
#     ans.next.val = add_fin(num1, num2)
#     pop_fin(num1)
#     pop_fin(num2)
#     ans.next.next.val = add_fin(num1,num2)
    
    
#     while get_fin(num1).val or get_fin(num2).val:
#         if get_fin(num1).val == None:
#             ans.val = (0 + get_fin(num2).val)
#             pop_fin(num2)
#             ans = ans.next
#             print_linked_list(ans,[])
        
#         elif get_fin(num2).val == None:
#             ans.val = (get_fin(num1).val + 0)
#             pop_fin(num1)
#             ans = ans.next
#             print_linked_list(ans,[]) 
        
#         else:
#             ans.val = (get_fin(num1).val + get_fin(num2).val)
#             pop_fin(num1)
#             pop_fin(num2)
#             print_linked_list(num1,[])
#             print_linked_list(num1,[])
#             print_linked_list(ans,[])
            
    print_linked_list(ans,[])
    
    return sort(ans)
    ##### End of your code #####

# %%
from linked_list_helper import ListNode

def P4(num1: ListNode, num2: ListNode) -> ListNode: 
    ##### Write your Code Here #####
    
    def get_next(curNode: ListNode) -> ListNode:
        try:
            return curNode.next
        except:
            return None
        
    def get_value(curNode: ListNode) -> int:
        if curNode == None:
            return 0
        else:
            return curNode.val
        
    def get_fin(curNode: ListNode) -> int:
        if curNode:
            while curNode.next != None:
                curNode = curNode.next
                num_fin = curNode
            return num_fin
        else:
            return 0
        
    def sort(curNode: ListNode) -> ListNode: 
        next = None
        curr = curNode
        prev = None
        while (curr != None):
            next = curr.next
            curr.next = prev
            prev = curr
            curr = next
        return prevå
    
    ans = ListNode()
    curr = ans
    node1 = num1
    node2 = num2
    carry = 0
    
    while True:
        i = get_value(node1)
        j = get_value(node2)
        
        sum_ = i + j + carry
        
        carry = sum_ // 10
        
        curr.next = ListNode(sum_ % 10)
        node1 = get_next(node1)
        node2 = get_next(node2)
        
        if node1 == None and node2 == None:
            break
        
        curr = curr.next
        
    if carry > 0:
        curr.next = ListNode(carry)
        
    return sort(ans.next)
    
    ##### End of your code #####

# %%
from linked_list_helper import *

def P4(num1: ListNode, num2: ListNode) -> ListNode: 
    ##### Write your Code Here #####
    
    def get_next(curNode: ListNode) -> ListNode:
        try:
            return curNode.next
        except:
            return None
        
    def get_value(curNode: ListNode) -> int:
        if curNode == None:
            return 0
        else:
            return curNode.val
        
    def sort(curNode: ListNode) -> ListNode: 
        next = None
        curr = curNode
        prev = None
        while (curr != None):
            next = curr.next
            curr.next = prev
            prev = curr
            curr = next
        return prev
    
    def add_two(num1: ListNode, num2: ListNode) -> ListNode:
        ans = head = ListNode(0)
        carry = 0

        while num1 or num2 or carry:
            sum_ = 0
            if num1:
                sum_ += num1.val
                num1 = num1.next
                
            if num2:
                sum_ += num2.val
                num2 = num2.next
            
            carry = (sum_ + carry) // 10
            val = (sum_ + carry) % 10
            
            head.next = ListNode(val) 
            head = head.next 

        return ans.next
    
    add_two(num1, num2)
    
#     sort(add_two(sort(num1), sort(num2)))
    
    ##### End of your code #####
