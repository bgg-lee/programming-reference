# %% [markdown]
# You are given the head of a linked list containing unique integer values and an integer array nums that is a subset of the linked list values.
#
# Return the number of connected components in nums where two values are connected if they appear consecutively in the linked list.
#
#
#
# Example 1:
#
#
# Input: head = [0,1,2,3], nums = [0,1,3]
# Output: 2
# Explanation: 0 and 1 are connected, so [0, 1] and [3] are the two connected components.
# Example 2:
#
#
# Input: head = [0,1,2,3,4], nums = [0,3,1,4]
# Output: 2
# Explanation: 0 and 1 are connected, 3 and 4 are connected, so [0, 1] and [3, 4] are the two connected components.
#
#
# Constraints:
#
# The number of nodes in the linked list is n.
# 1 <= n <= 104
# 0 <= Node.val < n
# All the values Node.val are unique.
# 1 <= nums.length <= n
# 0 <= nums[i] < n
# All the values of nums are unique.

# %%
temp = [1,5,2,6,1]
temp2 = [1,5,100]
s = set(temp)
s2 = set(temp2)
# s.intersection(s2)
# 1 in s
for i in s :
    print(i)
# Out:
# 1
# 2
# 5
# 6

# %%
# Python
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def numComponents(self, head: Optional[ListNode], nums: List[int]) -> int:
        ans = 0
        s = set(nums)
        while head :
            if head.val in s :
                ans += 1
                temp = head
                while temp and temp.val in s:
                    temp = temp.next
                head = temp
            else:
                head = head.next
        return ans

# %%
# C
/**
 * Definition for singly-linked list.
 * struct ListNode {
 *     int val;
 *     struct ListNode *next;
 * };
 */
bool find(int* a, int size, int target){
    for(int i=0;i<size;i++){
        if(a[i]==target) return true;
    }
    return false;
}

int numComponents(struct ListNode* head, int* nums, int numsSize) {
    int ans = 0;
    while(head){
        if(find(nums,numsSize,head->val)){
            ans++;
            struct ListNode* temp = head;
            while(temp && find(nums,numsSize,temp->val)){
                temp = temp->next;
            }
            head = temp;
        }
        else head = head->next;
    }
    return ans;
}

# %%
# C , hash table로 푼듯?
/**
 * Definition for singly-linked list.
 * struct ListNode {
 *     int val;
 *     struct ListNode *next;
 * };
 */
 
int numComponents(struct ListNode* head, int* nums, int numsSize) {
    // Create a hash set to store values in nums
    bool hash[10000] = { false };
    for (int i = 0; i < numsSize; i++) {
        hash[nums[i]] = true;
    }

    int components = 0;
    struct ListNode* current = head;

    while (current) {
        // Increment components count if current node is in nums and the next node isn't
        if (hash[current->val] && (!current->next || !hash[current->next->val])) {
            components++;
        }
        current = current->next;
    }

    return components;
}

# %%
# C++ // 
/**
 * Definition for singly-linked list.
 * struct ListNode {
 *     int val;
 *     ListNode *next;
 *     ListNode() : val(0), next(nullptr) {}
 *     ListNode(int x) : val(x), next(nullptr) {}
 *     ListNode(int x, ListNode *next) : val(x), next(next) {}
 * };
 */
class Solution {
public:
    int numComponents(ListNode* head, vector<int>& nums) {
        int ans = 0;
        while(head){
            if(find(nums.begin(),nums.end(),head->val)!=nums.end()){
                ans++;
                ListNode* temp = head;
                while(temp && find(nums.begin(),nums.end(),temp->val)!=nums.end()){
                    temp = temp->next;
                }
                head = temp;
            }
            else head = head->next;
        }
        return ans;
    }
};

# %%
# C++ unordred_set 은 auto it = s.find(3) 이런식으로 쓸 수 있고 *it은 3을 반환, 찾기 조건은 s.find(3) != s.end() 이런식으로 하면 된다. map이랑 같다.
/** 
 * Definition for singly-linked list.
 * struct ListNode {
 *     int val;
 *     ListNode *next;
 *     ListNode() : val(0), next(nullptr) {}
 *     ListNode(int x) : val(x), next(nullptr) {}
 *     ListNode(int x, ListNode *next) : val(x), next(next) {}
 * };
 */
class Solution {
public:
    int numComponents(ListNode* head, vector<int>& nums) {
        unordered_set<int> numSet(nums.begin(), nums.end());
        ListNode*li=head;
        int cnt=0;
        bool flag=false;
        while(li){
            if(numSet.count(li->val)){
               if(!flag){
                cnt++;
                flag=true;
               }
            }
            else{
                flag=false;
               }
            li=li->next;
        }
        return cnt;
    }
};
